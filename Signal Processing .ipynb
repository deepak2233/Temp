# %% [markdown]
# # Project AIM
# We are aiming to build a Emotion recognition/classifier (Happy,Sad,and Surprise, etc.) by using multimodal Datasets that contains Audio, Video, Language, and bio-signal. we will extract the features from 4 kinds of datasets via preprocessing before feeding into the neural network.
#
# # DataSets
# In our BioSignal DataSets i.e., [AMIGOS](http://www.eecs.qmul.ac.uk/mmv/datasets/amigos/download.html), We have 3 kind of Signal EEG, ECG, and EDA which we want to extract the feature bu using differet-diffrent method.
#
# # Table of Content
# - Introduction of the BioSignal and along with Artifacts
# - Preprocessing (In our Datasets has already been performed)
# - Feature Extraction

# %% [markdown]
# # EEG
# <b>Electroencephalography (EEG):</b> is an electrophysiological monitoring method to record electrical activity on the scalp that has been shown to represent the macroscopic activity of the surface layer of the brain underneath. It is typically non-invasive, with the electrodes placed along the scalp. Electrocorticography, involving invasive electrodes, is sometimes called intracranial EEG.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('D:\\Desktop\\Inria\\fnsys-14-00043-g001.jpg')
plt.figure(figsize=(10,10))
plt.title("MOdel")
plt.axis("off")
imgplot = plt.imshow(img)

# %% [markdown]
# # Preprocessing Work has been Done on EEG
# - The total EEG channel are 14 numberd from 1-14 with Channel Content <AF3, F7, F3, FC5, T7, P7, O1, O2P8, T8, FC6, F4, F8, AF4>
# - The data was downsampled at 128Hz.
# - A bandpass frequency filter from 4.0-45.0Hz was applied.

# %%
# %matplotlib inline
img = mpimg.imread('D:\\Desktop\\Inria\\111.png')
plt.figure(figsize=(10,10))
plt.title("EEG")
plt.axis("off")
imgplot = plt.imshow(img)

# %% [markdown]
# # ECG/EKG
# <b>Electrocardiography(ECG or EKG): </b> is the process of producing an electrocardiogram. It is a graph of voltage versus time of the electrical activity of the heart using electrodes placed on the skin. These electrodes detect the small electrical changes that are a consequence of cardiac muscle depolarization followed by repolarization during each cardiac cycle (heartbeat). Changes in the normal ECG pattern occur in numerous cardiac abnormalities, including cardiac rhythm disturbances (such as atrial fibrillation and ventricular tachycardia), inadequate coronary artery blood flow (such as myocardial ischemia and myocardial infarction), and electrolyte disturbances (such as hypokalemia and hyperkalemia).
#
# There are three main components to an ECG: the <b>P</b> wave, which represents the depolarization of the atria; the <b>QRS</b> complex, which represents the depolarization of the ventricles; and the <b>T</b> wave, which represents the repolarization of the ventricles.

# %%
# %matplotlib inline
img = mpimg.imread('D:\\Desktop\\Inria\\22222.png')
plt.figure(figsize=(5,5))
plt.title("ECG")
plt.axis("off")
imgplot = plt.imshow(img)

# %% [markdown]
# # Preprocessing Work has been Done on ECG
# - The total ECG channel are 2, numberd from 15-16 with Channel Content <ECG Right, ECH Left>
# - The data was downsampled at 128Hz.
# - ECG was low-pass filtered with 60Hz cut-off frequency.

# %%
# %matplotlib inline
img = mpimg.imread('D:\\Desktop\\Inria\\12.png')
plt.figure(figsize=(5,5))
plt.title("ECG")
plt.axis("off")
imgplot = plt.imshow(img)

# %% [markdown]
# # EDA/GSR
# Electrodermal activity (EDA; sometimes known as galvanic skin response, or GSR) refers to the variation of the electrical conductance of the skin in response to sweat secretion
# The EDA signal can also be reflective of the intensity of our emotional state, otherwise known as emotional arousal. Our level of emotional arousal changes in response to the environment and setting we’re in – if something is scary, threatening, joyful, or otherwise emotionally relevant, then the subsequent change in emotional response that we experience  that both positive (“happy” or “joyful”) and negative (“threatening” or “saddening”)

# %%
# %matplotlib inline
img = mpimg.imread('D:\\Desktop\\Inria\\EDA-signal-types-example.png')
plt.figure(figsize=(10,5))
plt.title("EDA")
plt.axis("off")
imgplot = plt.imshow(img)

# %% [markdown]
# # Preprocessing Work has been Done on EDA/GSR
# - GSR was reencoded to obtain skin conductance, and then GSR was calculated and low-pass filtered with 60Hz cut-off frequency.
# - The data was downsampled at 128Hz.

# %% [markdown]
# # Final Preprocessed DataSets

# %%
# %matplotlib inline
img = mpimg.imread('D:\\Desktop\\Inria\\31.png')
plt.figure(figsize=(10,10))
plt.title("DataSets")
plt.axis("off")
imgplot = plt.imshow(img)

# %% [markdown]
# ## Artifacts of EEG, ECG, & EDA

# %% [markdown]
# Artifacts may be defined as any unwanted interference which alters the accuracy of the reading obtained from the electrophysiological structure being studied. These may be caused by errors in the accusation of data such as patient movement , due to surrounding bioelectrical signals from other tissues or by the malfunctioning of the device that is utilised . Artifacts are found in EEGs , ECGs, and EDA given below:

# %% [markdown]
# ## EEG
# - Head Movement
# - eye movement (blink, lateral rectus spikes from lateral eye movement)
#
#
# The most common artifacts in EEG recordings are eye blinks and eye movements. Changes in the resting potential of the retina during eye-blinks and eye-movements as well as muscle activities of the eyelid during blinks produces disturbances in EEG recordings. They can be measured using an <b>Electrooculogram (EOG).</b>
#
# ## ECG
# - Respiration rate
# - Body Motion artifact
# - Heart rate
# - Blood pressure
# - Muscle tremor (or tension) artifact
#
# <b>Note:</b> Here Photoplethysmography (PPG) signal is also used as a biomedical signal. PPG is a non-invasive method in which relative blood volume changes in the blood close to skin is measured. The “pulse waveform” never underwent intensive investigation. Active investigation efforts are opening to reveal its effectiveness beyond oxygen saturation and determination of heart rate.
#
# ## EDA
# - When you feel an increase in stress, cognitive load, or emotion, your body will begin to sweat, causing you to produce a Skin Conductance Response (SCR) like the one pictured.
#
# <b>We will use cvxEDA Paper introduced by from Greco et al. It is based on a model which describes EDA as the sum of three terms: the phasic component, the tonic component, and an additive white Gaussian noise term incorporating model prediction errors as well as measurement errors and artifacts. This model is physiologically inspired and fully explains EDA through a rigorous methodology based on Bayesian statistics, mathematical convex optimization and sparsity</b>

# %%
# %matplotlib inline
img = mpimg.imread('D:\\Desktop\\Inria\\F2.png')
plt.figure(figsize=(10,10))
plt.title("Model")
plt.axis("off")
imgplot = plt.imshow(img)

# %% [markdown]
# # Artifact Removal
# - ICA(Independent Componets Analysis)
#
# <b>We will use ICA(Independent Componets Analysis) for remon=ving the artifacts from BioSignal(EEG, ECG, & EDA).</b>

# %% [markdown]
# # Methodology Used To Extract the Feature

# %% [markdown]
# - Spectral features
# - Spatial features
# - Temporal feature
#
# Every feature will be analyse by using two method
# - freq domain analysis
# - time-freq domain analysis

# %% [markdown]
# # We will Use below technique to extract the feature
# - Wavelet Tranformation
# - Statistical Feature
# - Power Spactral Entropy -PSE
# - Higher Order Spactral - HSO
# - Higher Order Crossing - HOC
# - NON Linear Feature

# %% [markdown]
# ### Wavelet transform and Fast Fourier Transform is used to decompose the each channel data into the five features i.e :-
#
# - Delta (< 4 Hz)
# - Theta (5-7 Hz)
# - Alpha (8-15 Hz)
# - Beta (16-31 Hz)
# - Gamma (> 32 Hz)

# %% [markdown]
# # Paper
# - https://www.hindawi.com/journals/tswj/2014/259121/
# - https://link.springer.com/article/10.3758/BF03209415
# - https://www.arxiv-vanity.com/papers/1911.12918/
# - https://github.com/pratyakshajha/emotion-recognition-by-deap-dataset/blob/master/Papers/Classification%20of%20emotional%20signals%20from%20DEAP%20dataset.pdf
#
# - https://github.com/pratyakshajha/emotion-recognition-by-deap-dataset/blob/master/Papers/Automatic%20detection%20of%20alertness.pdf
# - https://github.com/pratyakshajha/emotion-recognition-by-deap-dataset/blob/master/Papers/Classification%20of%20emotional%20signals%20from%20DEAP%20dataset.pdf
#
# - https://github.com/pratyakshajha/emotion-recognition-by-deap-dataset/blob/master/Papers/Feature%20Extractions%20and%20Selection%20for%20Emotion%20recognition%20from%20EEG.pdf
#
# - https://github.com/pratyakshajha/emotion-recognition-by-deap-dataset/tree/master/Papers
